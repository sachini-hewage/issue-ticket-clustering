# %%
#clustering_keywords.ipynb

# Set path
import sys
sys.path.append("../")

# %%
#All imports
from src.clustering_utils_keywords import run_keyword_clustering

# %%
# Run full clustering pipeline
df_clusters, model = run_keyword_clustering(
    method="hdbscan",          # Options: 'hdbscan' or 'kmeans'
    n_clusters=200,              # Only for KMeans
    min_cluster_size=3         # Minimum size for a cluster in HDBSCAN
)
# Out:
# Fetching keywords from DB...
# Retrieved 49800 tickets with keywords.
# Vectorizing keywords using TF-IDF...
# Clustering using HDBSCAN...
# /Users/sasha/enfuce-support-ai/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/sasha/enfuce-support-ai/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Found 3319 clusters (and 21403 noise points).
# Saving results to database...
# Keyword-based cluster IDs saved to 'ticket_embeddings'.
# Keyword clustering completed successfully.

# %%
#Inspect results
df_clusters.head(10)
# Out:
#     ticket_id                                           keywords  \
# 0  TKT-500000  rate limits transactions error, limits transac...
# 1  TKT-500001  kyc documents getting rejected, kyc documents ...
# 2  TKT-500002  pay online keeps declining, pay online keeps, ...
# 3  TKT-500003  prio card missing block, prio card missing, bl...
# 4  TKT-500004  tokenization failed wallet setup, tokenization...
# 5  TKT-500025  card damaged need replacement, card damaged ne...
# 6  TKT-500005  trouble integration sdk launch, trouble integr...
# 7  TKT-500006  prio increase api quota, increase api quota pr...
# 8  TKT-500007  card keeps getting declined, declined transact...
# 9  TKT-500008  commerce limit card gets, increase commerce li...
#
#                                         keywords_str  cluster_id
# 0  rate limits transactions error, limits transac...          -1
# 1  kyc documents getting rejected, kyc documents ...          -1
# 2  pay online keeps declining, pay online keeps, ...          -1
# 3  prio card missing block, prio card missing, bl...        1060
# 4  tokenization failed wallet setup, tokenization...         845
# 5  card damaged need replacement, card damaged ne...          -1
# 6  trouble integration sdk launch, trouble integr...        1209
# 7  prio increase api quota, increase api quota pr...          -1
# 8  card keeps getting declined, declined transact...         901
# 9  commerce limit card gets, increase commerce li...        1699

# %%
# Filter rows with this cluster
cluster_tickets = df_clusters[df_clusters["cluster_id"] == -1]
cluster_tickets
# Out:
#         ticket_id                                           keywords  \
# 0      TKT-500000  rate limits transactions error, limits transac...
# 1      TKT-500001  kyc documents getting rejected, kyc documents ...
# 2      TKT-500002  pay online keeps declining, pay online keeps, ...
# 5      TKT-500025  card damaged need replacement, card damaged ne...
# 7      TKT-500006  prio increase api quota, increase api quota pr...
# ...           ...                                                ...
# 49784  TKT-549983  webhook signatures failing verify, webhook sig...
# 49789  TKT-549989  kyc documents getting rejected, error question...
# 49794  TKT-549994  integration failing 500 webhook, failing 500 w...
# 49795  TKT-549995  increase api quota problem, increase api quota...
# 49796  TKT-549996  block certain mcc categories, block certain mc...
#
#                                             keywords_str  cluster_id
# 0      rate limits transactions error, limits transac...          -1
# 1      kyc documents getting rejected, kyc documents ...          -1
# 2      pay online keeps declining, pay online keeps, ...          -1
# 5      card damaged need replacement, card damaged ne...          -1
# 7      prio increase api quota, increase api quota pr...          -1
# ...                                                  ...         ...
# 49784  webhook signatures failing verify, webhook sig...          -1
# 49789  kyc documents getting rejected, error question...          -1
# 49794  integration failing 500 webhook, failing 500 w...          -1
# 49795  increase api quota problem, increase api quota...          -1
# 49796  block certain mcc categories, block certain mc...          -1
#
# [24209 rows x 4 columns]
